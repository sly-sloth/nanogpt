# %%
import torch
from v2 import *

# %%
model = torch.load("shakespeare_blabber.pth", weights_only=False, map_location=device)

# %%
model
# Out:
# GPTLanguageModel(
#   (token_embedding_table): Embedding(65, 384)
#   (position_embedding_table): Embedding(256, 384)
#   (blocks): Sequential(
#     (0): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-5): 6 x Head(
#             (key): Linear(in_features=384, out_features=64, bias=False)
#             (query): Linear(in_features=384, out_features=64, bias=False)
#             (value): Linear(in_features=384, out_features=64, bias=False)
#             (dropout): Dropout(p=0.2, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=384, out_features=1536, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=1536, out_features=384, bias=True)
#           (3): Dropout(p=0.2, inplace=False)
#         )
#       )
# ...

# %%
init_idx = torch.zeros((1, 1), dtype=torch.long, device=device)
max_new_tokens = 100

# %%
for i in range(1000//50):
    context = model.generate(init_idx, max_new_tokens=50)
    init_idx = context[:, -1:]
    print(decode(context[0].tolist()), end="")
# Out:
# PAULINA:
# Very' sir,
# The house, an all knowly's off this house.
#
# POLIXENES:
# My decies.
#
# KING HENRY VIIO:
# I knowbed you.
#
# SICINIUS:
# Madam, my lord, the hhich is trick doth us with her.
# Once it dher true,  thee
# As whose person are here's make me my lord atth sweet my heart;
# Which to league 'discredit, in hhpre sea, and to plink and tears,
# From all and weeppe, sir?
#
# Servant:
# My cure -cousin, I am a husband
#
#
# Provost:
# To Come hither by a gentleman. Welcome,  says,
# But with a sespirit, well commend my woman.
#
# VOLUMNIA:
# Not new you had mistock made the look
# Off wounds,
# You would have done, but fellow enough,
# AANA:
# Good gilt! Well, good make no morreless man!
#
#
# Go deving it.
#
# Fixth Gentlemen:
# Did so, had thus aard.
# 3etchets the o'clock the broth back, and thithhis heir.
#
# WARWICK:
# Why, let me say I?
#
# PRINCE EDWAAMPEY:
# You have turn mine obdutest;
# LAnd weeps petiifehe rock, when we're from myself times
# ...

# %%
torch.save(model.state_dict(), "shakespeare_blabber_state_dict.pth")
